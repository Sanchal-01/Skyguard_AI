# %%
from pathlib import Path
import sys


# Find the main project folder
current_path = Path.cwd()

project_root = None

for path in [current_path] + list(current_path.parents):
    if (path / "01_ml").exists():
        project_root = path
        break

if project_root is None:
    raise FileNotFoundError("Could not find the Skyguard_AI project folder.")


# Add our Python source folder
src_path = project_root / "01_ml" / "03_src"

sys.path.insert(0, str(src_path))

print("Project root:", project_root)
print("Source path :", src_path)
# Out:
# Project root: c:\Users\sanch\Documents\Git_hub\Skyguard_AI
# Source path : c:\Users\sanch\Documents\Git_hub\Skyguard_AI\01_ml\03_src

# %%
data_src_path = project_root / "01_ml" / "03_src" / "01_data"

sys.path.insert(0, str(data_src_path))

from loader import load_weather_data, check_data

print("Loader imported successfully!")
# Out:
# Loader imported successfully!

# %%
data_path = "C:/Users/sanch/Documents/Git_hub/Skyguard_AI/01_ml/01_data/02_processed/aws_stations_with_synthetic_humidity.csv"

sys.path.insert(0, str(data_path))

print("Dataset:", data_path)
# Out:
# Dataset: C:/Users/sanch/Documents/Git_hub/Skyguard_AI/01_ml/01_data/02_processed/aws_stations_with_synthetic_humidity.csv

# %%
df = load_weather_data(data_path)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (20888, 18)

# %%
check_data(df)
# Out:
# ========== DATA CHECK ==========
# Rows: 20888
# Columns: 18
# Stations: 14
# Date range: 2021-01-01 to 2025-02-10
# Duplicate rows: 0
# Duplicate station-date pairs: 0
# Missing humidity: 0
# Missing relative humidity: 0
# Invalid RH values: 0
# ...

# %%
df.head()
# Out:
#          cluster station_name state district date_of_record  avg_temp  \
# 0  Punjab Plains       Ambala    HR   Ambala     2021-01-01       9.1
# 1  Punjab Plains       Ambala    HR   Ambala     2021-01-02      11.8
# 2  Punjab Plains       Ambala    HR   Ambala     2021-01-03      14.6
# 3  Punjab Plains       Ambala    HR   Ambala     2021-01-04      18.1
# 4  Punjab Plains       Ambala    HR   Ambala     2021-01-05      16.2
#
#    min_temp  max_temp   humidity  relative_humidity_pct  dew_point_c  \
# 0       4.4      13.6  78.400208              78.400208     5.537342
# 1       5.7      14.6  75.500032              75.500032     7.606836
# 2       9.4      20.0  73.037773              73.037773     9.818830
# 3      11.2      23.2  64.934059              64.934059    11.398384
# 4      14.5      24.1  67.400295              67.400295    10.151256
#
#    absolute_humidity_g_m3  wind_speed  air_pressure  rainfall  elevation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20888 entries, 0 to 20887
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cluster                 20888 non-null  str
#  1   station_name            20888 non-null  str
#  2   state                   20888 non-null  str
#  3   district                20888 non-null  str
#  4   date_of_record          20888 non-null  datetime64[us]
#  5   avg_temp                20888 non-null  float64
#  6   min_temp                20885 non-null  float64
#  7   max_temp                20888 non-null  float64
#  8   humidity                20888 non-null  float64
#  9   relative_humidity_pct   20888 non-null  float64
#  10  dew_point_c             20888 non-null  float64
#  11  absolute_humidity_g_m3  20888 non-null  float64
#  12  wind_speed              20851 non-null  float64
#  13  air_pressure            20847 non-null  float64
# ...
